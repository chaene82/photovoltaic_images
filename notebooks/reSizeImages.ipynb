# %%
import os, sys
from PIL import Image

# %%
size = (192, 192)

# %%
folder_in = '../data/Rathausen_1280x1280'
folder_out = '../data/Rathausen_192x192'

onlyfiles = [f for f in os.listdir(folder_in) if os.path.isfile(os.path.join(folder_in, f))]

# %%
onlyfiles
# Out:
# ['20210312_105818.jpg',
#  '20210312_105822.jpg',
#  '20210312_105825.jpg',
#  '20210312_105835.jpg',
#  '20210312_110251.jpg',
#  '20210312_110253.jpg',
#  '20210312_110256.jpg',
#  '20210312_110302.jpg',
#  '20210312_110306.jpg',
#  '20210312_110308.jpg',
#  '20210312_110313.jpg',
#  '20210312_110315.jpg',
#  '20210312_110319.jpg',
#  '20210312_110325.jpg',
#  '20210312_110329.jpg',
#  '20210312_110332.jpg',
#  '20210312_110338.jpg',
#  '20210312_110343.jpg',
#  '20210312_110344.jpg',
#  '20210312_110346.jpg',
#  '20210312_110350.jpg',
#  '20210312_110351.jpg',
#  '20210312_110352.jpg',
#  '20210312_110355.jpg',
#  '20210312_110400.jpg',
#  '20210312_110403.jpg',
#  '20210312_110406.jpg',
#  '20210312_110553.jpg',
#  '20210312_110612.jpg',
#  '20210312_110620.jpg',
#  '20210312_110628.jpg',
#  '20210312_110631.jpg',
#  '20210312_110634.jpg',
#  '20210312_110637.jpg',
#  '20210312_110640.jpg',
#  '20210312_110643.jpg',
#  '20210312_110646.jpg',
#  '20210312_110713.jpg',
# ...

# %%
for _file in onlyfiles:
    infile = folder_in + "/" + _file
    outfile = folder_out + "/" + _file
    print(infile, outfile)
    try:
        im = Image.open(infile)
        out = im.resize(size, Image.ANTIALIAS)
        out.save(outfile, "JPEG")
    except IOError:
        print("cannot create smaller image for '%s'" % infil)
# Out:
# ../data/Rathausen_1280x1280/20210312_105818.jpg ../data/Rathausen_192x192/20210312_105818.jpg
# ../data/Rathausen_1280x1280/20210312_105822.jpg ../data/Rathausen_192x192/20210312_105822.jpg
# ../data/Rathausen_1280x1280/20210312_105825.jpg ../data/Rathausen_192x192/20210312_105825.jpg
# ../data/Rathausen_1280x1280/20210312_105835.jpg ../data/Rathausen_192x192/20210312_105835.jpg
# ../data/Rathausen_1280x1280/20210312_110251.jpg ../data/Rathausen_192x192/20210312_110251.jpg
# ../data/Rathausen_1280x1280/20210312_110253.jpg ../data/Rathausen_192x192/20210312_110253.jpg
# ../data/Rathausen_1280x1280/20210312_110256.jpg ../data/Rathausen_192x192/20210312_110256.jpg
# ../data/Rathausen_1280x1280/20210312_110302.jpg ../data/Rathausen_192x192/20210312_110302.jpg
# ../data/Rathausen_1280x1280/20210312_110306.jpg ../data/Rathausen_192x192/20210312_110306.jpg
# ../data/Rathausen_1280x1280/20210312_110308.jpg ../data/Rathausen_192x192/20210312_110308.jpg
# ...

# %%
os.walk(dir)
# Out:
# <generator object walk at 0x000001A38BBEA0C8>
